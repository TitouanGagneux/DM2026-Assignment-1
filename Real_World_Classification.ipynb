# %% [markdown]
# # Real World Classification

# %% [markdown]
# ## Load data

# %% [markdown]
# Import the necessary libraries

# %%
# If you do not use colab. You should install these packages.
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# !pip install graphviz

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

seed=40
np.random.seed(seed)

# %% [markdown]
# load the data

# %%
# Load data from the regularization demo CSV
df = pd.read_csv('data/NYCU_Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  BranchLength  \
# 0   1            7.0           NaN       4.700000           1.4          16.9
# 1   2            6.4           3.2       4.500000           1.5          16.4
# 2   3            6.9           NaN       4.900000           1.5          16.9
# 3   4            5.5           2.3       5.085612           1.3          15.6
# 4   5            6.5           2.8       4.600000           1.5          16.4
#
#    AvgDust  SepalLengthMajorAxis  SepalLengthMinorAxis  SepalLengthElongation  \
# 0     37.5              6.769877              6.755471               6.964281
# 1     95.1              6.202714              6.129652               6.201464
# 2     73.2              6.726317              6.762992               6.784647
# 3     59.9              5.608292              5.529096               5.382254
# 4     15.6              6.300774              6.443553               6.274360
#
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
missing_cols = [col for col in df.columns if df[col].isna().sum() > 0]

print("Columns with missing values:", missing_cols)

# 2. Calcul median et std pour ces colonnes
for col in missing_cols:
    median = df[col].median()
    std = df[col].std()
    print(f"{col} -> median: {median:.4f}, std: {std:.4f}")
# Out:
# Columns with missing values: ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'BranchLength']
# SepalLengthCm -> median: 6.3000, std: 1.0371
# SepalWidthCm -> median: 2.9000, std: 0.3896
# PetalLengthCm -> median: 5.0856, std: 1.5828
# PetalWidthCm -> median: 1.6000, std: 0.7067
# BranchLength -> median: 16.3000, std: 1.0352

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer

def data_preprocessing(df):
    # transform label to bi-class
    df['Species'] = df['Species'].astype(str).str.strip()
    le = LabelEncoder()
    df['Species'] = le.fit_transform(df['Species'])

    feature_cols = [c for c in df.columns if c not in ['Id', 'Species']]

    # transform string to number
    for col in feature_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    
    # TODO: Replace the missing values using “Nearest Neighbors Imputation”
    # ---------- Start your code below ----------
    imputer = KNNImputer(n_neighbors=5)
    df[feature_cols] = imputer.fit_transform(df[feature_cols])
    # ---------- --------------------- ----------
    
    return df, feature_cols

df, feature_cols = data_preprocessing(df)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  500.000000     500.000000    500.000000     500.000000    500.000000
# mean   250.500000       6.319840      2.837040       5.049883      1.684440
# std    144.481833       1.009275      0.372434       1.514955      0.694645
# min      1.000000       3.000000      1.500000       0.500000     -1.000000
# 25%    125.750000       5.800000      2.630000       4.500000      1.300000
# 50%    250.500000       6.300000      2.900000       5.035683      1.700000
# 75%    375.250000       6.700000      3.040000       5.300000      2.000000
# max    500.000000       9.600000      4.000000       9.200000      4.300000
#
#        BranchLength     AvgDust  SepalLengthMajorAxis  SepalLengthMinorAxis  \
# count    500.000000  500.000000            500.000000            500.000000
# mean      16.303440   46.745800              6.316422              6.323365
# ...

# %%
print("New values for columns with previous missing values:", missing_cols)

# 2. Calcul median et std pour ces colonnes
for col in missing_cols:
    median = df[col].median()
    std = df[col].std()
    print(f"{col} -> median: {median:.4f}, std: {std:.4f}")
# Out:
# New values for columns with previous missing values: ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'BranchLength']
# SepalLengthCm -> median: 6.3000, std: 1.0093
# SepalWidthCm -> median: 2.9000, std: 0.3724
# PetalLengthCm -> median: 5.0357, std: 1.5150
# PetalWidthCm -> median: 1.7000, std: 0.6946
# BranchLength -> median: 16.3000, std: 1.0110

# %% [markdown]
# ## Data Exploration

# %%
from sklearn.feature_selection import r_regression


# =========================
# 4.a Histogram
# =========================
plt.figure()
plt.hist(df['PetalWidthCm'],bins=20)
plt.xlabel('PetalWidthCm')
plt.ylabel('Frequency')
plt.title('Histogram of PetalWidthCm')
plt.show()

# %%
# =========================
# 4.b Correlation positive max
# =========================
features = [c for c in df.columns if c not in ['PetalWidthCm', 'Species', 'Id']]

X = df[features]
y = df['PetalWidthCm']

corr = r_regression(X, y)

corr_dict = dict(zip(features, corr))

# feature avec corrélation positive max
max_feature = max(corr_dict, key=corr_dict.get)
print("Max positive correlation feature:", max_feature, corr_dict[max_feature])
# Out:
# Max positive correlation feature: PetalWidthCompactness 0.9916701901370253

# %%
# =========================
# 4.c Top 5 corrélations négatives
# =========================
# trier par corr croissante (négatif)
sorted_corr = sorted(corr_dict.items(), key=lambda x: x[1])

top5_negative = sorted_corr[:5]

print("Top 5 negative correlations:")
for feat, val in top5_negative:
    print(feat, val)
# Out:
# Top 5 negative correlations:
# SepalWidthMajorAxis -0.09635042983649401
# SepalGlossIndex -0.09520000072196652
# SepalWidthCompactness -0.08849639559163792
# SepalWidthCurvature -0.08133438228330978
# SepalWidthMinorAxis -0.07439241023821906

# %%
# =========================
# 4.d Boxplot
# =========================
selected_features = [max_feature] + [feat for feat, _ in top5_negative]

plt.figure(figsize=(10, 5))
df[selected_features].boxplot()
plt.title('Boxplot of selected features')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Prepare the data

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

# normalize the data to [0,1]
for col in feature_cols:
    col_min = df[col].min()
    col_max = df[col].max()
    if col_max > col_min:
        df[col] = (df[col] - col_min) / (col_max - col_min)
    else:
        df[col] = 0.0
        
X = df[feature_cols].values.astype(float)
y = df['Species'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)

df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  BranchLength  \
# 0   1       0.606061         0.608       0.482759      0.452830      0.600000
# 1   2       0.515152         0.680       0.459770      0.471698      0.528571
# 2   3       0.590909         0.616       0.505747      0.471698      0.600000
# 3   4       0.378788         0.320       0.527082      0.433962      0.414286
# 4   5       0.530303         0.520       0.471264      0.471698      0.528571
#
#     AvgDust  SepalLengthMajorAxis  SepalLengthMinorAxis  \
# 0  0.376147              0.544026              0.529185
# 1  0.963303              0.464754              0.442295
# 2  0.740061              0.537937              0.530229
# 3  0.604485              0.381672              0.358911
# 4  0.152905              0.478459              0.485877
#
#    SepalLengthElongation  ...  LeafHueVariation  CanopyLightCapture  \
# 0               0.548614  ...          0.565095            0.580677
# ...

# %% [markdown]
# ### Train the model!

# %%
# Use the LinearModel to fit the data

from model.linear_model import LinearModel
from model.metrics import logloss
from model.gradients import logloss_sigmoid_grad
from model.utils import *
from model.activations import sigmoid

# Model configuration
loss_fn = logloss
act_fn = sigmoid
grad_fn = logloss_sigmoid_grad

np.random.seed(seed)
model = LinearModel(dim=X_train.shape[1], is_reg=False, loss_fn=loss_fn, act_fn=act_fn, grad_fn=grad_fn)
model.fit(X_train, y_train,lr=0.1, n_iteration =10000,val_ratio=0.2, reg_type='', reg_lambda=0.0)

# print model parameters
print("Model parameters (weights):", model.W)
# sum of absolute values of weights
print("Sum of absolute values of weights:", np.sum(np.abs(model.W)))
# Out:
# 50. Training loss: 0.6183886535310102, Val loss:0.6383381911771241
# 100. Training loss: 0.5960033921480784, Val loss:0.6229857283892484
# 150. Training loss: 0.5781690886526527, Val loss:0.611179684417757
# 200. Training loss: 0.5636439627476498, Val loss:0.6019785825360592
# 250. Training loss: 0.5515861130769195, Val loss:0.5947349187857767
# 300. Training loss: 0.5414115554176107, Val loss:0.5889917649142379
# 350. Training loss: 0.5327055446405081, Val loss:0.584418742874043
# 400. Training loss: 0.5251667000245236, Val loss:0.58077162665673
# 450. Training loss: 0.5185712433977272, Val loss:0.5778662753932695
# 500. Training loss: 0.5127496761323889, Val loss:0.5755614147648994
# 550. Training loss: 0.5075712624849853, Val loss:0.5737469965121451
# 600. Training loss: 0.5029334978289509, Val loss:0.5723361523089564
# 650. Training loss: 0.49875481918863024, Val loss:0.571259514930716
# 700. Training loss: 0.4949694641429734, Val loss:0.5704611319860385
# ...

# %% [markdown]
# ## Metrics

# %%
# use evaluate_binary_classifier to evaluate the model on the test set
from model.metrics import evaluate_binary_classifier

y_pred = model.predict(X_test)
evaluate_binary_classifier(y_test, y_pred)
# Out:
# Model Evaluation
# Accuracy  : 0.7200
# Precision : 0.7125
# Recall    : 0.7500
# F1-score  : 0.7308
# {'Accuracy': 0.72,
#  'Precision': 0.7125,
#  'Recall': 0.75,
#  'F1-score': 0.7307692307692307}
